# %%
import requests
from config import XENTRAL_BASE_URL
from config import XENTRAL_BEARER_TOKEN

url = "https://66019bcae7d18.xentral.biz/api/v1/artikel?filter%5B0%5D%5Bproperty%5D=nummer&filter%5B0%5D%5Bexpression%5D=eq&filter%5B0%5D%5Bvalue%5D=CAP23002_03&include=lagerbestand&items=1"
headers = {
        "Authorization": f"Bearer {XENTRAL_BEARER_TOKEN or 'missing'}",
        "Content-Type": "application/json",
        "Accept": "application/json",
    }

res = requests.get(url=url, headers=headers)
print(res.json())
# Out:
# {'error': {'code': 7452, 'http_code': 404, 'message': 'Resource not found', 'href': 'https://66019bcae7d18.xentral.biz/api/docs.html#error-7452'}}
