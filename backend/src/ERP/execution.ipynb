# %%
import requests
import json 
xentralID = '66019bcae7d18'
baseURL = f"https://{xentralID}.xentral.biz"
bearerToken = '3|pqBa4oTF2BfCBCt0HPjy0ywBwTw0EktwkW5HfNaN'
headers_auth = {
    "Authorization": f"Bearer {bearerToken}",
    #"Accept": "application/vnd.xentral.default.v1+json"
}
#url = "/api/v1/salesOrders?filter[0][key]=orderDate&filter[0][op]=greaterThan&filter[0][value]=2025-11-18T00:00:00+01:00&filter[1][key]=orderDate&filter[1][op]=lessThan&filter[1][value]=2026-01-01T00:00:00+01:00"
#url = "/api/v1/salesOrders"
#url = "/api/v1/belege/auftraege?filter[0][property]=tatsaechlichesLieferdatum&filter[0][expression]=gte&filter[0][value]=2025-01-01T00%3A00%2B01%3A00&filter[1][property]=tatsaechlicheslieferdatum&filter[1][expression]=lte&filter[1][value]=2026-01-01T00%3A00%2B01%3A00&include=positionen&items=1000"
#url = "/api/v1/belege/auftraege?include=positionen"
#url = "/api/v1/artikel/2"
query = "SELECT * FROM users"
url = "/api/v1/analytics/query"
out = requests.post(url=baseURL+url, headers=headers_auth, data={'query': query})
print(out.status_code)
# Out:
# 402

# %%
from erp_analyst import XentralAgent
agent = XentralAgent()
question = "Zeige mir alle Stücklisten für die nächsten 6 Wochen."
agent(question)
# Out:
# User Question: Zeige mir alle Stücklisten für die nächsten 6 Wochen.
#
# --- Step 1: Selecting Tool ---
# Tool Plan: [ToolCall(name='get_future_boms', args={'time_quantity': '6', 'time_unit': 'weeks'})]
#
# --- Step 2: Executing Tool ---
# Calling: get_future_boms with args {'time_quantity': '6', 'time_unit': 'weeks'}
# [Tool: get_future_boms] Started for 6 weeks
# [API Call] GET Sales Orders: 2025-11-19T00:00+01:00 to 2025-12-31T00:00+01:00
# 200
# https://66019bcae7d18.xentral.biz/api/v1/belege/auftraege?filter%5B0%5D%5Bproperty%5D=tatsaechlichesLieferdatum&filter%5B0%5D%5Bexpression%5D=gte&filter%5B0%5D%5Bvalue%5D=2025-11-19T00%3A00%2B01%3A00&filter%5B1%5D%5Bproperty%5D=tatsaechlichesLieferdatum&filter%5B1%5D%5Bexpression%5D=lte&filter%5B1%5D%5Bvalue%5D=2025-12-31T00%3A00%2B01%3A00&include=positionen&items=1000
# 2
# [{'id': 900, 'firma': 1, 'projekt': '1', 'status': 'freigegeben', 'belegnr': 'AT-2024-059561', 'kundennummer': '10002', 'lieferantenauftrag': 0, 'lieferant': 0, 'aktion': '', 'angebot': '', 'ihrebestellnummer': '4507831949', 'internet': '4507831949', 'internebezeichnung': '', 'datum': '2023-05-15', 'lieferdatum': '2025-11-28', 'lieferdatumkw': 0, 'tatsaechlicheslieferdatum': '2025-11-26', 'reservationdate': None, 'abweichendebezeichnung': 0, 'adresse': 81, 'typ': 'firma', 'name': 'Heidelberger Druckmaschinen AG', 'titel': '', 'ansprechpartnerid': 0, 'ansprechpartner': '', 'abteilung': '', 'unterabteilung': '', 'adresszusatz': '', 'strasse': 'Gutenbergstr.', 'plz': '69168', 'ort': 'Wiesloch', 'land': 'DE', 'bundesstaat': '', 'telefon': '', 'telefax': '06222/82993707', 'email': '', 'anschreiben': 'Sehr geehrter Herr Bender', 'gesamtsumme': '6.59', 'erloes_netto': '5.54', 'umsatz_netto': '5.54', 'lager_ok': 1, 'porto_ok': 1, 'ust_ok': 1, 'check_ok': 1, 'vorkasse_ok': 1, 'nachnahme_ok': 1, 'reserviert_ok': 0, 'partnerid': 0, 'folgebestaetigung': '0000-00-00', 'zahlungsmail': '0000-00-00', 'liefertermin_ok': 0, 'teillieferung_moeglich': 0, 'kreditlimit_ok': 1, 'kreditlimit_freigabe': 0, 'liefersperre_ok': 1, 'teillieferungvon': 0, 'teillieferungnummer': 0, 'autofreigabe': 0, 'freigabe': 0, 'nachbesserung': 0, 'abgeschlossen': 0, 'nachlieferung': 0, 'versandart': 'DHL', 'lieferbedingung': '', 'autoversand': 1, 'keinporto': 0, 'art': '', 'fastlane': 0, 'lieferungtrotzsperre': 0, 'keinestornomail': 0, 'keinetrackingmail': None, 'zahlungsmailcounter': None, 'zahlungsweise': 'rechnung', 'zahlungszieltage': 30, 'zahlungszieltageskonto': 10, 'zahlungszielskonto': '0.00', 'skontobetrag': '0.0000', 'skontoberechnet': 1, 'abweichendelieferadresse': 0, 'liefername': '', 'liefertitel': '', 'lieferansprechpartner': '', 'lieferabteilung': '', 'lieferunterabteilung': '', 'lieferadresszusatz': '', 'lieferstrasse': '', 'lieferort': '', 'lieferplz': '', 'lieferland': '', 'lieferbundesstaat': '', 'lieferemail': '', 'lieferid': 0, 'liefergln': '', 'versendet': 0, 'versendet_am': '0000-00-00 00:00:00', 'versendet_per': '', 'versendet_durch': '', 'angebotid': None, 'gln': '', 'bearbeiterid': 0, 'bearbeiter': '', 'ohne_artikeltext': None, 'ustid': 'DE 143455661', 'ust_befreit': 0, 'ust_inner': 0, 'anzeigesteuer': 0, 'waehrung': 'EUR', 'sprache': 'deutsch', 'kurs': '0.00000000', 'kostenstelle': '', 'freitext': '', 'internebemerkung': '', 'bodyzusatz': '', 'shop': 0, 'shopextid': '', 'shopextstatus': '', 'positionen': [{'id': 3191, 'auftrag': 900, 'projekt': 1, 'artikel': 5892, 'bezeichnung': '', 'beschreibung': '', 'nummer': '00.681.0606/', 'menge': '1.0000', 'preis': '5.54000000', 'waehrung': 'EUR', 'lieferdatum': '0000-00-00', 'vpe': '', 'umsatzsteuer': '', 'bemerkung': '', 'geliefert': 0, 'geliefert_menge': '0.0000', 'einheit': '', 'webid': None, 'rabatt': '0.00', 'nachbestelltexternereinkauf': None, 'potentiellerliefertermin': None, 'zolleinzelwert': '0.00000000', 'zollgesamtwert': '0.00000000', 'zollwaehrung': '', 'zolleinzelgewicht': '0.00000000', 'zollgesamtgewicht': '0.00000000', 'zolltarifnummer': '', 'herkunftsland': '', 'artikelnummerkunde': '', 'lieferdatumkw': 0, 'einkaufspreis': '0.00000000', 'einkaufspreisurspruenglich': '5.54000000', 'ohnepreis': 0, 'steuersatz': None, 'steuertext': None, 'steuerbetrag': None, 'skontobetrag': None, 'skontosperre': 0, 'ausblenden_im_pdf': 0}]}, {'id': 901, 'firma': 1, 'projekt': '1', 'status': 'freigegeben', 'belegnr': 'AT-2024-059562', 'kundennummer': '10002', 'lieferantenauftrag': 0, 'lieferant': 0, 'aktion': '', 'angebot': '', 'ihrebestellnummer': '4507831953', 'internet': '4507831953', 'internebezeichnung': '', 'datum': '2023-05-15', 'lieferdatum': '2025-11-28', 'lieferdatumkw': 0, 'tatsaechlicheslieferdatum': '2025-11-26', 'reservationdate': None, 'abweichendebezeichnung': 0, 'adresse': 81, 'typ': 'firma', 'name': 'Heidelberger Druckmaschinen AG', 'titel': '', 'ansprechpartnerid': 0, 'ansprechpartner': ...
# [Logic] Found 107 unique products in 172 orders.
# Got Result length: 92246 chars
#
# --- Step 3: Synthesizing Answer ---
# Final Answer: Ich habe 102 Produkte mit Stücklisten für den Zeitraum vom 19. November 2025 bis zum 31. Dezember 2025 gefunden. Hier sind einige Beispiele:
#
# *   **Leitungssatz Verdrah.FC102-105-24V (Produkt ID: 5432):**
#     *   V30AE000029 (KAKO-0002139) - Menge: 3.0000
#     *   V30AE000027 (KAKO-0002138) - Menge: 3.0000
#     *   V30AE000026 (KAKO-0002137) - Menge: 3.0000
#     *   V30AE000135 (KAKO-0002136) - Menge: 2.0000
#     *   V30AE000622 (KAKO-0002135) - Menge: 1.0000
#     *   4160700 (KAKO-0002102) - Menge: 1.2000
#     *   4160426 K (KAKO-0001851) - Menge: 1.5000
#     *   4160414K (KAKO-0001751) - Menge: 2.6000
#     *   Material Divers (KAKO-0001486) - Menge: 2.0000
#     *   V30AE000013 (KAKO-0000970) - Menge: 36.0000
#
# *   **Anschlussleitung Luefter Zone 1+2a Bo. (Produkt ID: 1463):**
#     *   Material Divers (KAKO-0001486) - Menge: 1.0000
#     *   VN02-015-0047-2U (KAKO-0001332) - Menge: 8.0000
#     *   T3377-550 (KAKO-0001330) - Menge: 2.0000
#     *   TTW-3725V/ (KAKO-0001173) - Menge: 1.0000
#     *   1873375 (KAKO-0001040) - Menge: 1.0000
#     *   V30AE000013 (KAKO-0000970) - Menge: 8.0000
#     *   0015205 (KAKO-0000409) - Menge: 4.2000
#     *   61831001 (KAKO-0000352) - Menge: 1.0000
#
# *   **Anschlussleitung Sensor Lackfuellstand (Produkt ID: 3128):**
#     *   LLPA-07A.50 (KAKO-0001947) - Menge: 1.2000
#     *   TTW-3725V/ (KAKO-0001173) - Menge: 3.0000
#     *   1534805-1 (KAKO-0000878) - Menge: 1.0000
#     *   167292-1 (KAKO-0000742) - Menge: 1.0000
#     *   166053-1 (KAKO-0000705) - Menge: 4.0000
#     *   242888 (KAKO-0000110) - Menge: 1.0000
#
# ...und so weiter für die restlichen 99 Produkte.
# 'Ich habe 102 Produkte mit Stücklisten für den Zeitraum vom 19. November 2025 bis zum 31. Dezember 2025 gefunden. Hier sind einige Beispiele:\n\n*   **Leitungssatz Verdrah.FC102-105-24V (Produkt ID: 5432):**\n    *   V30AE000029 (KAKO-0002139) - Menge: 3.0000\n    *   V30AE000027 (KAKO-0002138) - Menge: 3.0000\n    *   V30AE000026 (KAKO-0002137) - Menge: 3.0000\n    *   V30AE000135 (KAKO-0002136) - Menge: 2.0000\n    *   V30AE000622 (KAKO-0002135) - Menge: 1.0000\n    *   4160700 (KAKO-0002102) - Menge: 1.2000\n    *   4160426 K (KAKO-0001851) - Menge: 1.5000\n    *   4160414K (KAKO-0001751) - Menge: 2.6000\n    *   Material Divers (KAKO-0001486) - Menge: 2.0000\n    *   V30AE000013 (KAKO-0000970) - Menge: 36.0000\n\n*   **Anschlussleitung Luefter Zone 1+2a Bo. (Produkt ID: 1463):**\n    *   Material Divers (KAKO-0001486) - Menge: 1.0000\n    *   VN02-015-0047-2U (KAKO-0001332) - Menge: 8.0000\n    *   T3377-550 (KAKO-0001330) - Menge: 2.0000\n    *   TTW-3725V/ (KAKO-0001173) - Menge: 1.0000\n    *   1873375 (KAKO-0001040) - Menge: 1.0000\n    *   V30AE000013 (KAKO-0000970) - Menge: 8.0000\n    *   0015205 (KAKO-0000409) - Menge: 4.2000\n    *   61831001 (KAKO-0000352) - Menge: 1.0000\n\n*   **Anschlussleitung Sensor Lackfuellstand (Produkt ID: 3128):**\n    *   LLPA-07A.50 (KAKO-0001947) - Menge: 1.2000\n    *   TTW-3725V/ (KAKO-0001173) - Menge: 3.0000\n    *   1534805-1 (KAKO-0000878) - Menge: 1.0000\n    *   167292-1 (KAKO-0000742) - Menge: 1.0000\n    *   166053-1 (KAKO-0000705) - Menge: 4.0000\n    *   242888 (KAKO-0000110) - Menge: 1.0000\n\n...und so weiter für die restlichen 99 Produkte.'
